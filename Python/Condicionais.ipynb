# %% [markdown]
# # Condicionais em Python
# Este notebook explica **condicionais em Python** em detalhes, com exemplos e exercícios.

# %% [markdown]
# ## 1. O que são condicionais?
# Condicionais permitem que um programa tome decisões. Elas executam diferentes blocos de código dependendo se uma condição é verdadeira (`True`) ou falsa (`False`).

# %%
idade = 20

if idade >= 18:
    print("Maior de idade")
# Out:
# Maior de idade

# %% [markdown]
# ## 2. Estrutura do `if`
#
# Sintaxe:
#
# ```python
# if condição:
#     bloco_de_código
# ```
#
# A condição deve resultar em `True` ou `False`.
# Os blocos são definidos pela **indentação** (espaços no início da linha).

# %%
nota = 8

if nota >= 7:
    print("Aprovado")
print("Fim do programa")
# Out:
# Aprovado
# Fim do programa

# %% [markdown]
# ## 3. O `else`
#
# O `else` executa quando a condição do `if` é falsa.

# %%
nota = 5

if nota >= 7:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Reprovado

# %% [markdown]
# ## 4. O `elif`
#
# Quando existem várias possibilidades, utiliza-se `elif`.

# %%
nota = 8.5

if nota >= 9:
    print("Excelente")
elif nota >= 7:
    print("Aprovado")
elif nota >= 5:
    print("Recuperação")
else:
    print("Reprovado")
# Out:
# Aprovado

# %% [markdown]
# ## 7. Condicionais aninhadas
#
# É possível colocar um `if` dentro de outro.

# %%
idade = 25
possui_ingresso = True

if idade >= 18:
    if possui_ingresso:
        print("Entrada permitida")
    else:
        print("Compre um ingresso")
else:
    print("Entrada proibida")
# Out:
# Entrada permitida

# %% [markdown]
# ## 8. Verdadeiro e Falso em Python
#
# São considerados falsos:
#
# - `False`
# - `0`
# - `0.0`
# - `None`
# - `""`
# - `[]`
# - `{}`
# - `set()`
#
# Quase todos os demais valores são verdadeiros.

# %%
lista = []

if lista:
    print("Tem elementos")
else:
    print("Lista vazia")
# Out:
# Lista vazia

# %% [markdown]
# ## 9. Operador ternário
#
# Forma reduzida de escrever um `if/else`.

# %%
idade = 17

resultado = "Maior" if idade >= 18 else "Menor"
print(resultado)
# Out:
# Menor

# %% [markdown]
# # Exercícios

# %% [markdown]
# 1. Leia uma idade e informe se é maior de idade.

# %%
idade = 10
if idade >= 18:
    resultado = "Maior"
else:
    resultado = "Menor"
print(resultado)
# Out:
# Menor

# %% [markdown]
# 2. Leia duas notas e informe a média e a situação.

# %%
nota1 = 10
nota2 = 4
soma = nota1 + nota2   
media = soma / 2

if media >= 7:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Aprovado

# %% [markdown]
# 3. Verifique se um número é positivo, negativo ou zero.

# %%
numero = -4
if numero > 0:
    print("Positivo")
else:
    print("Negativo")
# Out:
# Negativo

# %% [markdown]
# 4. Determine se um ano é bissexto.

# %%
ano = int(input("Digite um ano:"))
if ano % 4 == 0:
    if ano % 100 == 0:
        if ano % 400 == 0:
            print("Ano bissexto")
        else:
            print("Ano não bissexto")
    else:
        print("Ano bissexto")

# %% [markdown]
# 5. Faça um menu simples usando `if/elif/else`.

# %%
teste = input("Digite algo:")
if teste.isnumeric():
    print("É um número")
else:
    print("Não é um número")
# Out:
# É um número
