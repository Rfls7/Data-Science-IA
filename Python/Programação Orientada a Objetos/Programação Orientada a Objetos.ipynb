# %% [markdown]
# # 🧱 Programação Orientada a Objetos (POO) em Python
#
# Este notebook apresenta os principais conceitos de **Programação Orientada a Objetos (POO)** em Python, com exemplos, boas práticas e exercícios.
#
# ## Objetivos
#
# - Entender classes e objetos
# - Criar atributos e métodos
# - Utilizar construtores
# - Aplicar encapsulamento, herança e polimorfismo
# - Conhecer métodos especiais e boas práticas

# %% [markdown]
# # Orientação a Objetos (POO) Explicada Como se Você Tivesse 10 Anos 🧸
#
# Imagine que você está brincando com vários carrinhos. Cada carrinho tem uma cor, um modelo e uma velocidade. Além disso, todos eles podem acelerar, frear e buzinar.
#
# A Programação Orientada a Objetos (POO) funciona exatamente assim: ela organiza os programas usando **objetos**, que representam coisas do mundo real.
#
# ---
#
# # O que é um Objeto?
#
# Um **objeto** é uma coisa que possui:
#
# - Características (atributos)
# - Ações (métodos)
#
# Por exemplo:
#
# 🚗 Carrinho
#
# Características:
# - Cor: Vermelho
# - Modelo: Ferrari
# - Velocidade: 0 km/h
#
# Ações:
# - Acelerar
# - Frear
# - Buzinar
#
# Na programação seria algo parecido com:
#
# ```text
# Carrinho
#
# Cor: Vermelho
# Modelo: Ferrari
# Velocidade: 0
#
# Ações:
# - acelerar()
# - frear()
# - buzinar()
# ```
#
# ---
#
# # O que é uma Classe?
#
# Uma **classe** é como uma fábrica ou um molde.
#
# Imagine um molde de carrinho.
#
# Com o mesmo molde você pode criar:
#
# - Um carrinho vermelho
# - Um carrinho azul
# - Um carrinho preto
#
# Todos são diferentes, mas foram feitos usando o mesmo molde.
#
# ```text
# Classe Carrinho
#
#         ↓
#
#   🚗 Vermelho
#   🚙 Azul
#   🚕 Preto
# ```
#
# A classe diz:
#
# > "Todo carrinho terá uma cor, um modelo e poderá acelerar."
#
# Mas ela ainda não é um carrinho de verdade.
#
# ---
#
# # O que é uma Instância?
#
# Quando você usa a classe para criar um objeto, isso se chama **instância**.
#
# Exemplo:
#
# Classe:
#
# ```text
# Carrinho
# ```
#
# Instâncias:
#
# ```text
# MeuCarrinho
# CarrinhoDoJoão
# CarrinhoDaMaria
# ```
#
# Cada um possui suas próprias informações.
#
# ---
#
# # Exemplo em Python
#
# ```python
# class Carrinho:
#
#     def __init__(self, cor, modelo):
#         self.cor = cor
#         self.modelo = modelo
#         self.velocidade = 0
#
#     def acelerar(self):
#         self.velocidade += 10
#
#     def buzinar(self):
#         print("Biiii!")
# ```
#
# Criando um carrinho:
#
# ```python
# meu_carro = Carrinho("Vermelho", "Ferrari")
# ```
#
# Agora existe um objeto chamado `meu_carro`.
#
# ---
#
# # Atributos
#
# São as informações que um objeto guarda.
#
# Exemplo:
#
# ```python
# meu_carro.cor
# ```
#
# Resultado:
#
# ```text
# Vermelho
# ```
#
# Outro exemplo:
#
# ```python
# meu_carro.modelo
# ```
#
# Resultado:
#
# ```text
# Ferrari
# ```
#
# Essas informações são chamadas de **atributos**.
#
# ---
#
# # Métodos
#
# São as ações que um objeto pode fazer.
#
# Exemplo:
#
# ```python
# meu_carro.acelerar()
# ```
#
# Depois disso:
#
# ```text
# Velocidade = 10
# ```
#
# Outro método:
#
# ```python
# meu_carro.buzinar()
# ```
#
# Resultado:
#
# ```text
# Biiii!
# ```
#
# ---
#
# # Exemplo do Cachorro 🐶
#
# Classe:
#
# ```text
# Cachorro
# ```
#
# Características:
#
# - Nome
# - Idade
# - Raça
#
# Ações:
#
# - Latir
# - Comer
# - Dormir
#
# Objetos:
#
# ```text
# Rex
# Bob
# Mel
# ```
#
# Todos são cachorros.
#
# Mas cada um possui seus próprios dados.
#
# ---
#
# # Encapsulamento 📦
#
# Imagine uma televisão.
#
# Você aperta o botão de ligar.
#
# Ela liga.
#
# Mas você não precisa saber como a eletricidade funciona lá dentro.
#
# Você apenas usa.
#
# Isso é **Encapsulamento**.
#
# O objeto esconde os detalhes internos e mostra apenas o que precisamos usar.
#
# ```text
# Você
#
# ↓
#
# [Ligar]
#
# ↓
#
# TV liga
# ```
#
# Você não precisa mexer nos fios.
#
# ---
#
# # Herança 👨‍👦
#
# Imagine que existe uma classe chamada:
#
# ```text
# Animal
# ```
#
# Todo animal pode:
#
# - Comer
# - Dormir
#
# Agora criamos outra classe:
#
# ```text
# Cachorro
# ```
#
# O cachorro também pode:
#
# - Comer
# - Dormir
#
# Mas além disso:
#
# - Latir
#
# Ou seja:
#
# ```text
# Animal
#    │
#    └── Cachorro
# ```
#
# O cachorro **herda** tudo que o Animal sabe fazer.
#
# Exemplo:
#
# ```python
# class Animal:
#
#     def comer(self):
#         print("Comendo")
#
# class Cachorro(Animal):
#
#     def latir(self):
#         print("Au Au")
# ```
#
# Agora:
#
# ```python
# rex = Cachorro()
#
# rex.comer()
# rex.latir()
# ```
#
# Resultado:
#
# ```text
# Comendo
# Au Au
# ```
#
# ---
#
# # Polimorfismo 🎭
#
# Essa palavra parece difícil, mas a ideia é simples.
#
# Imagine três animais.
#
# ```text
# Cachorro
# Gato
# Vaca
# ```
#
# Todos possuem o método:
#
# ```text
# fazer_som()
# ```
#
# Mas cada um responde diferente.
#
# ```text
# Cachorro → Au Au
#
# Gato → Miau
#
# Vaca → Muu
# ```
#
# Mesmo método.
#
# Resultados diferentes.
#
# Exemplo:
#
# ```python
# class Cachorro:
#     def fazer_som(self):
#         print("Au Au")
#
# class Gato:
#     def fazer_som(self):
#         print("Miau")
# ```
#
# ---
#
# # Abstração 🎨
#
# Imagine um controle remoto.
#
# Você aperta:
#
# ▶️ Play
#
# O filme começa.
#
# Você não precisa entender como o sinal chega até a TV.
#
# Você apenas usa.
#
# A abstração mostra apenas o que é importante.
#
# Esconde toda a parte complicada.
#
# ---
#
# # Resumindo
#
# | Conceito | Explicação |
# |----------|------------|
# | Classe | O molde para criar objetos |
# | Objeto | Uma coisa criada a partir da classe |
# | Atributos | Informações do objeto |
# | Métodos | Ações que o objeto pode fazer |
# | Encapsulamento | Esconde os detalhes internos |
# | Herança | Uma classe aproveita outra |
# | Polimorfismo | A mesma ação pode ter resultados diferentes |
# | Abstração | Mostrar apenas o necessário |
#
# ---
#
# # Comparação com LEGO 🧱
#
# Imagine uma caixa de LEGO.
#
# A **classe** é o manual de montagem.
#
# Cada carrinho montado é um **objeto**.
#
# Cada carrinho pode ter:
#
# - Cor diferente
# - Rodas diferentes
# - Adesivos diferentes
#
# Mas todos seguem o mesmo manual.
#
# ```text
# Classe (Manual)
#
#         ↓
#
# Objeto 1 🚗
#
# Objeto 2 🚙
#
# Objeto 3 🚕
# ```
#
# ---
#
# # A ideia principal da Orientação a Objetos
#
# Em vez de criar programas pensando apenas em funções e variáveis, pensamos em **coisas do mundo real**.
#
# Por exemplo:
#
# - Pessoa
# - Cachorro
# - Carro
# - Conta Bancária
# - Livro
# - Celular
# - Escola
# - Aluno
#
# Cada uma dessas coisas possui:
#
# - Dados (atributos)
# - Comportamentos (métodos)
#
# Assim, o código fica mais organizado, fácil de entender, reutilizar e manter.

# %%
#Definindo uma função em Python
def contagem():
    result = 1 + 1 
    return result

#Chamando a função
contagem()
# Out:
# 2

# %% [markdown]
# ## 1. O que é POO?
#
# A Programação Orientada a Objetos organiza o código em **objetos**, que representam entidades do mundo real. Cada objeto possui **atributos** (características) e **métodos** (ações).

# %% [markdown]
# ## 2. Criando uma classe

# %%
# Define uma classe chamada Pessoa.
# Neste momento ela não possui atributos nem métodos.
# A instrução 'pass' é usada apenas para indicar que o bloco da classe está vazio.
class Pessoa:
    pass

# Cria um objeto (instância) da classe Pessoa.
# A variável 'p1' passa a referenciar esse novo objeto.
p1 = Pessoa()

# Exibe o tipo do objeto criado.
# O resultado será: <class '__main__.Pessoa'>
print(type(p1))
# Out:
# <class '__main__.Pessoa'>

# %% [markdown]
# ## 3. Atributos e métodos

# %%
# Define a classe Pessoa.
class Pessoa:

    # Define um método chamado 'apresentar'.
    # O parâmetro 'self' representa o próprio objeto que está chamando o método.
    def apresentar(self):
        print("Olá! Eu sou uma pessoa.")

# Cria um objeto (instância) da classe Pessoa.
p = Pessoa()

# Chama o método 'apresentar' do objeto 'p'.
# Como o método pertence ao objeto, utilizamos a notação objeto.metodo().
p.apresentar()
# Out:
# Olá! Eu sou uma pessoa.

# %% [markdown]
# ## 4. O construtor (`__init__`)

# %%
# Define a classe Pessoa.
class Pessoa:

    # O método especial __init__ é chamado automaticamente
    # sempre que um novo objeto é criado.
    # Ele é utilizado para inicializar os atributos do objeto.
    def __init__(self, nome, idade):
        self.nome = nome      # Armazena o nome do objeto
        self.idade = idade    # Armazena a idade do objeto

    # Método responsável por apresentar as informações da pessoa.
    def apresentar(self):
        print(f"Meu nome é {self.nome} e tenho {self.idade} anos.")

# Cria um objeto da classe Pessoa.
# Os valores "Ana" e 28 são enviados para o construtor (__init__).
p = Pessoa("Ana", 28)

# Chama o método apresentar() para exibir os dados do objeto.
p.apresentar()
# Out:
# Meu nome é Ana e tenho 28 anos.

# %% [markdown]
# ## 5. Atributos de instância

# %%
class Produto:
    def __init__(self, nome, preco):
        self.nome = nome
        self.preco = preco

produto = Produto("Notebook", 3500)
print(produto.nome)
print(produto.preco)
# Out:
# Notebook
# 3500

# %% [markdown]
# ## 6. Atributos de classe

# %%
class Conta:
    banco = "Banco Python"

    def __init__(self, titular):
        self.titular = titular

c = Conta("Carlos")
print(c.banco)
print(Conta.banco)
# Out:
# Banco Python
# Banco Python

# %% [markdown]
# ## 7. Encapsulamento

# %%
# Define a classe Conta.
class Conta:

    # Construtor da classe.
    # Recebe o saldo inicial da conta.
    def __init__(self, saldo):

        # O atributo __saldo é privado.
        # O uso de dois underscores (__) indica que ele não deve ser acessado
        # diretamente fora da classe.
        self.__saldo = saldo

    # Método para depositar um valor na conta.
    def depositar(self, valor):

        # Soma o valor informado ao saldo atual.
        self.__saldo += valor

    # Método para consultar o saldo da conta.
    def consultar_saldo(self):

        # Retorna o saldo armazenado.
        return self.__saldo

# Cria uma conta com saldo inicial de R$ 100.
c = Conta(100)

# Deposita R$ 50 na conta.
c.depositar(50)

# Exibe o saldo atualizado.
print(c.consultar_saldo())
# Out:
# 150

# %% [markdown]
# ## 8. Herança

# %%
# Classe base (ou classe pai).
# Ela representa um animal de forma genérica.
class Animal:

    # Método que representa o som emitido por um animal.
    def emitir_som(self):
        print("Au Au!")


# Classe Cachorro.
# Ela herda todas as características da classe Animal.
class Cachorro(Animal):
    pass


# Cria um objeto da classe Cachorro.
dog = Cachorro()

# Chama o método emitir_som().
# A classe cachorro não possui esse método, mas como ela herda da classe Animal,
dog.emitir_som()
# Out:
# Au Au!

# %% [markdown]
# ## 9. Polimorfismo

# %%
# Define a classe Gato.
class Gato:

    # Método responsável por emitir o som do gato.
    def emitir_som(self):
        print("Miau")


# Define a classe Vaca.
class Vaca:

    # Método responsável por emitir o som da vaca.
    def emitir_som(self):
        print("Muu")


# Cria uma lista contendo um objeto da classe Gato
# e um objeto da classe Vaca.
for animal in [Gato(), Vaca()]:

    # Chama o método emitir_som() para cada objeto.
    # O Python executa o método correspondente à classe do objeto.
    animal.emitir_som()
# Out:
# Miau
# Muu

# %% [markdown]
# ## 10. Métodos especiais

# %%
# Define a classe Livro.
class Livro:

    # Construtor da classe.
    # Recebe o título do livro e o armazena no atributo 'titulo'.
    def __init__(self, titulo):
        self.titulo = titulo

    # Método especial __str__().
    # Ele define como o objeto será representado em formato de texto.
    # Esse método é chamado automaticamente quando utilizamos print().
    def __str__(self):
        return f"Livro: {self.titulo}"

# Cria um objeto da classe Livro e o imprime na tela.
print(Livro("Python para Todos"))
# Out:
# Livro: Python para Todos

# %% [markdown]
# ## 11. Propriedades (`@property`)

# %%
# Define a classe Pessoa.
class Pessoa:

    # Construtor da classe.
    # Recebe a idade e a armazena no atributo _idade.
    def __init__(self, idade):
        self._idade = idade

    # O decorador @property transforma o método 'idade'
    # em um atributo de leitura.
    # Assim, podemos acessar a idade sem usar parênteses.
    @property
    def idade(self):
        return self._idade

# Cria um objeto da classe Pessoa com idade igual a 30.
p = Pessoa(30)

# Acessa a propriedade 'idade' e imprime seu valor.
print(p.idade)
# Out:
# 30

# %% [markdown]
# ## 12. Métodos de classe e estáticos

# %%
# Define a classe Calculadora.
class Calculadora:

    # O decorador @staticmethod indica que este método
    # não depende de um objeto nem da própria classe.
    # Ele funciona como uma função comum, mas organizada dentro da classe.
    @staticmethod
    def somar(a, b):
        return a + b

    # O decorador @classmethod indica que este método
    # recebe a própria classe como primeiro parâmetro (cls).
    @classmethod
    def descricao(cls):
        return f"Classe: {cls.__name__}"

# Chama o método estático sem criar um objeto.
print(Calculadora.somar(2, 3))

# Chama o método de classe.
print(Calculadora.descricao())
# Out:
# 5
# Classe: Calculadora

# %% [markdown]
# ## 13. Resumo
#
# | Conceito | Descrição |
# |---|---|
# | Classe | Modelo para criar objetos |
# | Objeto | Instância de uma classe |
# | Atributo | Característica do objeto |
# | Método | Ação do objeto |
# | `__init__` | Construtor |
# | Herança | Reutilização entre classes |
# | Polimorfismo | Mesmo método, comportamentos diferentes |
# | Encapsulamento | Proteção dos dados |
# | `@property` | Acesso controlado a atributos |

# %% [markdown]
# ## 14. Boas práticas
#
# - Dê nomes claros às classes (PascalCase).
# - Prefira métodos curtos e com uma responsabilidade.
# - Utilize encapsulamento quando necessário.
# - Evite duplicação de código com herança ou composição.
# - Documente classes e métodos importantes.

# %% [markdown]
# ## 15. Exercícios
#
#
# 2. Crie uma classe `Retangulo` com um método que calcule a área.
# 3. Implemente uma classe `ContaBancaria` com depósito e saque.
# 4. Crie uma classe `Funcionario` e uma classe `Gerente` que herde dela.
# 5. Sobrescreva um método em uma classe filha.
# 6. Implemente `__str__` em uma classe de sua escolha.
# 7. Utilize `@property` para validar um atributo.

# %% [markdown]
# 1. Crie uma classe `Carro` com marca e modelo.

# %%
class Carro:
    def __init__(self, marca, modelo, ano):
        self.marca = marca
        self.modelo = modelo
        self.ano = ano

Carro("Toyota", "Corolla", 2020)

# %% [markdown]
# 2. Crie uma classe `Retangulo` com um método que calcule a área.

# %%
class Retangulo:
    def __init__(self, base, altura):
        self.base = base
        self.altura = altura

    def area(self):
        return self.base * self.altura

# Exemplo de uso da classe Retangulo
r = Retangulo(5, 3)
print(r.area())  # Saída: 15
# Out:
# 15
